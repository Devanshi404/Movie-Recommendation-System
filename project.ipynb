# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv("tmdb_5000_credits.csv")
df.reset_index(inplace = True)
df.head()
# Out:
#    index  movie_id                                     title  \
# 0      0     19995                                    Avatar
# 1      1       285  Pirates of the Caribbean: At World's End
# 2      2    206647                                   Spectre
# 3      3     49026                     The Dark Knight Rises
# 4      4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
df.shape
# Out:
# (4803, 5)

# %%
features = ['movie_id' , 'title' , 'cast' , 'crew']
df[features].head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
df[features].isnull().values.any()
# Out:
# np.False_

# %%
def combine_features(row):
    return row['movie_id']+' '+row['title']+' '+row['cast']+' '+row['crew']

# %%
count_matrix = CountVectorizer().fit_transform(df['crew'])
cosine_sim = cosine_similarity(count_matrix)
print(cosine_sim)
# Out:
# [[1.         0.95317455 0.98678375 ... 0.90460132 0.72243161 0.83699884]
#  [0.95317455 1.         0.95960533 ... 0.94511902 0.74185023 0.87578137]
#  [0.98678375 0.95960533 1.         ... 0.92009212 0.7326647  0.84834869]
#  ...
#  [0.90460132 0.94511902 0.92009212 ... 1.         0.72228544 0.87785039]
#  [0.72243161 0.74185023 0.7326647  ... 0.72228544 1.         0.72011904]
#  [0.83699884 0.87578137 0.84834869 ... 0.87785039 0.72011904 1.        ]]

# %%
cosine_sim.shape
# Out:
# (4803, 4803)

# %%
def get_title_from_index(index):
    return df[df.index == index]["title"].values[0]
def get_index_from_title(title):
    return df[df.title == title]["index"].values[0]

# %%
movie_user_likes = "John Carter" 
movie_index = get_index_from_title(movie_user_likes)

similar_movies = list(enumerate(cosine_sim[movie_index]))

# %%
print(similar_movies)
# Out:
# [(0, np.float64(0.9647425605454233)), (1, np.float64(0.9629587243241523)), (2, np.float64(0.9727817325070918)), (3, np.float64(0.9781056809480556)), (4, np.float64(0.9999999999999956)), (5, np.float64(0.9540739150408032)), (6, np.float64(0.9415708914633901)), (7, np.float64(0.9666979420133932)), (8, np.float64(0.9619786381104299)), (9, np.float64(0.9824770139174409)), (10, np.float64(0.9194717312700168)), (11, np.float64(0.9357589269542596)), (12, np.float64(0.9451378780235988)), (13, np.float64(0.9458074383894907)), (14, np.float64(0.9706896871165868)), (15, np.float64(0.9751435724476075)), (16, np.float64(0.9600359333610909)), (17, np.float64(0.9403260707185492)), (18, np.float64(0.9578524134262479)), (19, np.float64(0.974499070519391)), (20, np.float64(0.9702923111479097)), (21, np.float64(0.9547652652485679)), (22, np.float64(0.978949503924657)), (23, np.float64(0.9607066606461158)), (24, np.float64(0.9731675797235897)), (25, np.float64(0.9739068515650474)), (26, np.float64(0.9780998447189462)), (27, np.float64(0.9714809025535917)), (28, np.float64(0.9696960659713211)), (29, np.float64(0.9660241864772218)), (30, np.float64(0.9792654320351877)), (31, np.float64(0.9327344283586206)), (32, np.float64(0.9396411930783004)), (33, np.float64(0.9615150332046223)), (34, np.float64(0.9038595866800818)), (35, np.float64(0.9603659428952281)), (36, np.float64(0.9663749857138076)), (37, np.float64(0.9558846389796106)), (38, np.float64(0.9816698589944608)), (39, np.float64(0.9519993998412478)), (40, np.float64(0.9574505226407872)), (41, np.float64(0.980334782529984)), (42, np.float64(0.9499330661714107)), (43, np.float64(0.9590441655626726)), (44, np.float64(0.9811165357060853)), (45, np.float64(0.9427222571357334)), (46, np.float64(0.9681308550887696)), (47, np.float64(0.9764338435093767)), (48, np.float64(0.9573459915059739)), (49, np.float64(0.9324938995525807)), (50, np.float64(0.9351902504647559)), (51, np.float64(0.9558728959129468)), (52, np.float64(0.9586186955645533)), (53, np.float64(0.9299960236801104)), (54, np.float64(0.8865657922941408)), (55, np.float64(0.940903329919044)), (56, np.float64(0.9760450960580004)), (57, np.float64(0.9707592911921947)), (58, np.float64(0.9443777096947198)), (59, np.float64(0.9605583836004122)), (60, np.float64(0.9118340990820819)), (61, np.float64(0.9542517132503169)), (62, np.float64(0.9172194773724855)), (63, np.float64(0.9516728709026673)), (64, np.float64(0.978641104436867)), (65, np.float64(0.9779298169497739)), (66, np.float64(0.9563981639573852)), (67, np.float64(0.9047617409330314)), (68, np.float64(0.9434212715679408)), (69, np.float64(0.9735368286874186)), (70, np.float64(0.9122090034395394)), (71, np.float64(0.9169362733699755)), (72, np.float64(0.9812164795571382)), (73, np.float64(0.9403613348205604)), (74, np.float64(0.9777845335296099)), (75, np.float64(0.9715353615455459)), (76, np.float64(0.9546678106308634)), (77, np.float64(0.9518036562259872)), (78, np.float64(0.9544320008082637)), (79, np.float64(0.9506528946786178)), (80, np.float64(0.9658453638628871)), (81, np.float64(0.9365036352333235)), (82, np.float64(0.9807189115435742)), (83, np.float64(0.9822292259622286)), (84, np.float64(0.9685165172450586)), (85, np.float64(0.9662832880244551)), (86, np.float64(0.8655002888133293)), (87, np.float64(0.9801570472557557)), (88, np.float64(0.9512801750523971)), (89, np.float64(0.9578303113223758)), (90, np.float64(0.9786621015595728)), (91, np.float64(0.9842410396458104)), (92, np.float64(0.9492088919279044)), (93, np.float64(0.977244107954323)), (94, np.float64(0.9621091488983411)), (95, np.float64(0.9801664961469368)), (96, np.float64(0.9481586224951449)), (97, np.float64(0.9397702197409362)), (98, np.float64(0.9652362243240757)), (99, np.float64(0.9728332661147616)), (100, np.float64(0.9785183204816167)), (101, np.float64(0.9603912998689879)), (102, np.float64(0.986910449369869)), (103, np.float64(0.873425110308991)), (104, np.float64(0.9403174605273555)), (105, np.float64(0.968 ...

# %%
sorted_similar_movies = sorted(similar_movies , key = lambda x:x[1] , reverse=(True))

# %%
i = 0
print("Top 7 similar movies to "+movie_user_likes+" are:\n")
for element in sorted_similar_movies:
    print(get_title_from_index(element[0]))
    i=i+1
    if i>=7:
        break
# Out:
# Top 7 similar movies to John Carter are:
#
# John Carter
# The Hunger Games: Mockingjay - Part 2
# Taken 3
# Frequency
# The Big Short
# Catch Me If You Can
# The Conjuring 2
